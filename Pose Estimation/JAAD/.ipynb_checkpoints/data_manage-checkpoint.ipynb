# %%
from jaad_data import *
import sys
sys.path.append('/home/ubuntu/niviru/poseflow-pie/Pose Estimation/')
from pose_estimation import *
import pandas as pd

# %%
j = JAAD(data_path=".")
train_data = j.generate_data_trajectory_sequence("train")
val_data = j.generate_data_trajectory_sequence("val")
test_data = j.generate_data_trajectory_sequence("test")
# Out:
# ---------------------------------------------------------
# Generating action sequence data
# fstride: 1
# sample_type: all
# subset: all_videos
# width_rng: [60, inf]
# squarify_ratio: 0
# data_split_type: default
# seq_type: crossing
# min_track_size: 15
# random_params: {'ratios': None, 'val_data': True, 'regen_data': False}
# ---------------------------------------------------------
# Generating database for jaad
# jaad database loaded from /home/ubuntu/niviru/poseflow-pie/Pose Estimation/JAAD/data_cache/jaad_database.pkl
# ---------------------------------------------------------
# Generating crossing data
# Split: train
# Number of pedestrians: 1405
# Total number of samples: 406
# ---------------------------------------------------------
# Generating action sequence data
# fstride: 1
# sample_type: all
# subset: all_videos
# width_rng: [60, inf]
# squarify_ratio: 0
# data_split_type: default
# seq_type: crossing
# min_track_size: 15
# random_params: {'ratios': None, 'val_data': True, 'regen_data': False}
# ---------------------------------------------------------
# Generating database for jaad
# jaad database loaded from /home/ubuntu/niviru/poseflow-pie/Pose Estimation/JAAD/data_cache/jaad_database.pkl
# ---------------------------------------------------------
# Generating crossing data
# Split: val
# Number of pedestrians: 209
# Total number of samples: 60
# ---------------------------------------------------------
# Generating action sequence data
# fstride: 1
# sample_type: all
# subset: all_videos
# width_rng: [60, inf]
# squarify_ratio: 0
# data_split_type: default
# seq_type: crossing
# min_track_size: 15
# random_params: {'ratios': None, 'val_data': True, 'regen_data': False}
# ---------------------------------------------------------
# Generating database for jaad
# jaad database loaded from /home/ubuntu/niviru/poseflow-pie/Pose Estimation/JAAD/data_cache/jaad_database.pkl
# ---------------------------------------------------------
# Generating crossing data
# Split: test
# Number of pedestrians: 1089
# Total number of samples: 333

# %%
def get_sequence_dict(data_dict):
    new_dict = {key + "_seq": [] for key in list(data_dict.keys())[:-1]}
    for i in range(len(data_dict['image'])):
        print("Getting sequence data for {}...".format("/".join(data_dict['image'][i][0].split("/")[:-1])))
        j = 0
        while (j + 14) <= len(data_dict['image'][i]):
            if not any(data_dict['occlusion'][i][j:j+14]):
                for new_key, key in zip(new_dict.keys(), data_dict.keys()):
                    new_dict[new_key].append(np.squeeze(np.array(data_dict[key][i][j:j+14])))
            j += 1
    return new_dict

# %%
train_seq = get_sequence_dict(train_data)
val_seq = get_sequence_dict(val_data)
test_seq = get_sequence_dict(test_data)
# Out:
# Getting sequence data for ./images/video_0001...
# Getting sequence data for ./images/video_0001...
# Getting sequence data for ./images/video_0001...
# Getting sequence data for ./images/video_0003...
# Getting sequence data for ./images/video_0003...
# Getting sequence data for ./images/video_0007...
# Getting sequence data for ./images/video_0007...
# Getting sequence data for ./images/video_0009...
# Getting sequence data for ./images/video_0014...
# Getting sequence data for ./images/video_0019...
# Getting sequence data for ./images/video_0019...
# Getting sequence data for ./images/video_0020...
# Getting sequence data for ./images/video_0020...
# Getting sequence data for ./images/video_0025...
# Getting sequence data for ./images/video_0026...
# Getting sequence data for ./images/video_0026...
# Getting sequence data for ./images/video_0026...
# Getting sequence data for ./images/video_0026...
# Getting sequence data for ./images/video_0027...
# Getting sequence data for ./images/video_0027...
# Getting sequence data for ./images/video_0027...
# Getting sequence data for ./images/video_0030...
# Getting sequence data for ./images/video_0030...
# Getting sequence data for ./images/video_0030...
# Getting sequence data for ./images/video_0030...
# Getting sequence data for ./images/video_0031...
# Getting sequence data for ./images/video_0037...
# Getting sequence data for ./images/video_0037...
# Getting sequence data for ./images/video_0037...
# Getting sequence data for ./images/video_0037...
# Getting sequence data for ./images/video_0038...
# Getting sequence data for ./images/video_0038...
# Getting sequence data for ./images/video_0038...
# Getting sequence data for ./images/video_0038...
# Getting sequence data for ./images/video_0039...
# Getting sequence data for ./images/video_0039...
# Getting sequence data for ./images/video_0039...
# Getting sequence data for ./images/video_0039...
# Getting sequence data for ./images/video_0039...
# Getting sequence data for ./images/video_0039...
# Getting sequence data for ./images/video_0047...
# Getting sequence data for ./images/video_0050...
# Getting sequence data for ./images/video_0050...
# Getting sequence data for ./images/video_0050...
# Getting sequence data for ./images/video_0052...
# Getting sequence data for ./images/video_0052...
# Getting sequence data for ./images/video_0054...
# Getting sequence data for ./images/video_0056...
# Getting sequence data for ./images/video_0060...
# Getting sequence data for ./images/video_0061...
# Getting sequence data for ./images/video_0061...
# Getting sequence data for ./images/video_0061...
# Getting sequence data for ./images/video_0062...
# Getting sequence data for ./images/video_0062...
# Getting sequence data for ./images/video_0062...
# Getting sequence data for ./images/video_0062...
# Getting sequence data for ./images/video_0062...
# Getting sequence data for ./images/video_0064...
# Getting sequence data for ./images/video_0064...
# Getting sequence data for ./images/video_0066...
# Getting sequence data for ./images/video_0078...
# Getting sequence data for ./images/video_0078...
# Getting sequence data for ./images/video_0079...
# Getting sequence data for ./images/video_0080...
# Getting sequence data for ./images/video_0080...
# Getting sequence data for ./images/video_0080...
# Getting sequence data for ./images/video_0081...
# Getting sequence data for ./images/video_0081...
# Getting sequence data for ./images/video_0083...
# Getting sequence data for ./images/video_0085...
# Getting sequence data for ./images/video_0088...
# Getting sequence data for ./images/video_0091...
# Getting sequence data for ./images/video_0094...
# Getting sequence data for ./images/video_0094...
# Getting sequence data for ./images/video_0095...
# Getting sequence data for ./images/video_0095...
# Getting sequence data for ./images/video_0095...
# Getting sequence data for ./images/video_0095...
# Getting sequence data for ./images/video_0098...
# Getting sequence data for ./images/video_0098...
# Getting sequence data for ./images/video_0098...
# Getting sequence data for ./images/video_0108...
# Getting sequence data for ./images/video_0108...
# Getting sequence data for ./images/video_0108...
# Getting sequence data for ./images/video_0108...
# Getting sequence data for ./images/video_0108...
# Getting sequence data for ./images/video_0109...
# Getting sequence data for ./images/video_0109...
# Getting sequence data for ./images/video_0109...
# Getting sequence data for ./images/video_0109...
# Getting sequence data for ./images/video_0111...
# Getting sequence data for ./images/video_0111...
# Getting sequence data for ./images/video_0112...
# Getting sequence data for ./images/video_0112...
# Getting sequence data for ./images/video_0112...
# Getting sequence data for ./images/video_0112...
# Getting sequence data for ./images/video_0120...
# Getting sequence data for ./images/video_0121...
# Getting sequence data for ./images/video_0122...
# Getting sequence data for ./images/video_0122...
# Getting sequence data for ./images/video_0129...
# Getting sequence data for ./images/video_0130...
# Getting sequence data for ./images/video_0131...
# Getting sequence data for ./images/video_0131...
# Getting sequence data for ./images/video_0131...
# Getting sequence data for ./images/video_0131...
# Getting sequence data for ./images/video_0131...
# Getting sequence data for ./images/video_0132...
# Getting sequence data for ./images/video_0132...
# Getting sequence data for ./images/video_0132...
# Getting sequence data for ./images/video_0132...
# Getting sequence data for ./images/video_0132...
# Getting sequence data for ./images/video_0133...
# Getting sequence data for ./images/video_0134...
# Getting sequence data for ./images/video_0134...
# Getting sequence data for ./images/video_0136...
# Getting sequence data for ./images/video_0136...
# Getting sequence data for ./images/video_0136...
# Getting sequence data for ./images/video_0136...
# Getting sequence data for ./images/video_0137...
# Getting sequence data for ./images/video_0138...
# Getting sequence data for ./images/video_0138...
# Getting sequence data for ./images/video_0138...
# Getting sequence data for ./images/video_0138...
# Getting sequence data for ./images/video_0138...
# Getting sequence data for ./images/video_0139...
# Getting sequence data for ./images/video_0139...
# Getting sequence data for ./images/video_0139...
# Getting sequence data for ./images/video_0139...
# Getting sequence data for ./images/video_0139...
# Getting sequence data for ./images/video_0140...
# Getting sequence data for ./images/video_0143...
# Getting sequence data for ./images/video_0145...
# Getting sequence data for ./images/video_0145...
# Getting sequence data for ./images/video_0145...
# Getting sequence data for ./images/video_0146...
# Getting sequence data for ./images/video_0146...
# Getting sequence data for ./images/video_0146...
# Getting sequence data for ./images/video_0147...
# Getting sequence data for ./images/video_0147...
# Getting sequence data for ./images/video_0149...
# Getting sequence data for ./images/video_0149...
# Getting sequence data for ./images/video_0149...
# Getting sequence data for ./images/video_0149...
# Getting sequence data for ./images/video_0149...
# Getting sequence data for ./images/video_0154...
# Getting sequence data for ./images/video_0154...
# Getting sequence data for ./images/video_0154...
# Getting sequence data for ./images/video_0157...
# Getting sequence data for ./images/video_0157...
# Getting sequence data for ./images/video_0157...
# Getting sequence data for ./images/video_0157...
# Getting sequence data for ./images/video_0158...
# Getting sequence data for ./images/video_0158...
# Getting sequence data for ./images/video_0158...
# Getting sequence data for ./images/video_0159...
# Getting sequence data for ./images/video_0159...
# Getting sequence data for ./images/video_0159...
# Getting sequence data for ./images/video_0161...
# Getting sequence data for ./images/video_0166...
# Getting sequence data for ./images/video_0166...
# Getting sequence data for ./images/video_0169...
# Getting sequence data for ./images/video_0169...
# Getting sequence data for ./images/video_0171...
# Getting sequence data for ./images/video_0174...
# Getting sequence data for ./images/video_0174...
# Getting sequence data for ./images/video_0175...
# Getting sequence data for ./images/video_0175...
# Getting sequence data for ./images/video_0175...
# Getting sequence data for ./images/video_0175...
# Getting sequence data for ./images/video_0175...
# Getting sequence data for ./images/video_0176...
# Getting sequence data for ./images/video_0176...
# Getting sequence data for ./images/video_0176...
# Getting sequence data for ./images/video_0180...
# Getting sequence data for ./images/video_0180...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0186...
# Getting sequence data for ./images/video_0188...
# Getting sequence data for ./images/video_0188...
# Getting sequence data for ./images/video_0188...
# Getting sequence data for ./images/video_0189...
# Getting sequence data for ./images/video_0190...
# Getting sequence data for ./images/video_0190...
# Getting sequence data for ./images/video_0190...
# Getting sequence data for ./images/video_0191...
# Getting sequence data for ./images/video_0192...
# Getting sequence data for ./images/video_0192...
# Getting sequence data for ./images/video_0192...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0194...
# Getting sequence data for ./images/video_0196...
# Getting sequence data for ./images/video_0198...
# Getting sequence data for ./images/video_0200...
# Getting sequence data for ./images/video_0200...
# Getting sequence data for ./images/video_0202...
# Getting sequence data for ./images/video_0204...
# Getting sequence data for ./images/video_0204...
# Getting sequence data for ./images/video_0204...
# Getting sequence data for ./images/video_0204...
# Getting sequence data for ./images/video_0208...
# Getting sequence data for ./images/video_0209...
# Getting sequence data for ./images/video_0210...
# Getting sequence data for ./images/video_0210...
# Getting sequence data for ./images/video_0215...
# Getting sequence data for ./images/video_0215...
# Getting sequence data for ./images/video_0215...
# Getting sequence data for ./images/video_0218...
# Getting sequence data for ./images/video_0218...
# Getting sequence data for ./images/video_0218...
# Getting sequence data for ./images/video_0218...
# Getting sequence data for ./images/video_0219...
# Getting sequence data for ./images/video_0219...
# Getting sequence data for ./images/video_0225...
# Getting sequence data for ./images/video_0225...
# Getting sequence data for ./images/video_0225...
# Getting sequence data for ./images/video_0227...
# Getting sequence data for ./images/video_0227...
# Getting sequence data for ./images/video_0228...
# Getting sequence data for ./images/video_0229...
# Getting sequence data for ./images/video_0229...
# Getting sequence data for ./images/video_0231...
# Getting sequence data for ./images/video_0231...
# Getting sequence data for ./images/video_0231...
# Getting sequence data for ./images/video_0231...
# Getting sequence data for ./images/video_0231...
# Getting sequence data for ./images/video_0231...
# Getting sequence data for ./images/video_0232...
# Getting sequence data for ./images/video_0235...
# Getting sequence data for ./images/video_0235...
# Getting sequence data for ./images/video_0235...
# Getting sequence data for ./images/video_0235...
# Getting sequence data for ./images/video_0236...
# Getting sequence data for ./images/video_0236...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0237...
# Getting sequence data for ./images/video_0241...
# Getting sequence data for ./images/video_0242...
# Getting sequence data for ./images/video_0242...
# Getting sequence data for ./images/video_0242...
# Getting sequence data for ./images/video_0242...
# Getting sequence data for ./images/video_0246...
# Getting sequence data for ./images/video_0247...
# Getting sequence data for ./images/video_0247...
# Getting sequence data for ./images/video_0247...
# Getting sequence data for ./images/video_0249...
# Getting sequence data for ./images/video_0249...
# Getting sequence data for ./images/video_0249...
# Getting sequence data for ./images/video_0250...
# Getting sequence data for ./images/video_0250...
# Getting sequence data for ./images/video_0250...
# Getting sequence data for ./images/video_0250...
# Getting sequence data for ./images/video_0250...
# Getting sequence data for ./images/video_0254...
# Getting sequence data for ./images/video_0255...
# Getting sequence data for ./images/video_0255...
# Getting sequence data for ./images/video_0255...
# Getting sequence data for ./images/video_0255...
# Getting sequence data for ./images/video_0257...
# Getting sequence data for ./images/video_0260...
# Getting sequence data for ./images/video_0260...
# Getting sequence data for ./images/video_0260...
# Getting sequence data for ./images/video_0262...
# Getting sequence data for ./images/video_0262...
# Getting sequence data for ./images/video_0262...
# Getting sequence data for ./images/video_0262...
# Getting sequence data for ./images/video_0262...
# Getting sequence data for ./images/video_0264...
# Getting sequence data for ./images/video_0264...
# Getting sequence data for ./images/video_0264...
# Getting sequence data for ./images/video_0266...
# Getting sequence data for ./images/video_0266...
# Getting sequence data for ./images/video_0266...
# Getting sequence data for ./images/video_0266...
# Getting sequence data for ./images/video_0266...
# Getting sequence data for ./images/video_0266...
# Getting sequence data for ./images/video_0268...
# Getting sequence data for ./images/video_0268...
# Getting sequence data for ./images/video_0268...
# Getting sequence data for ./images/video_0268...
# Getting sequence data for ./images/video_0268...
# Getting sequence data for ./images/video_0268...
# Getting sequence data for ./images/video_0269...
# Getting sequence data for ./images/video_0269...
# Getting sequence data for ./images/video_0269...
# Getting sequence data for ./images/video_0272...
# Getting sequence data for ./images/video_0272...
# Getting sequence data for ./images/video_0272...
# Getting sequence data for ./images/video_0272...
# Getting sequence data for ./images/video_0272...
# Getting sequence data for ./images/video_0275...
# Getting sequence data for ./images/video_0276...
# Getting sequence data for ./images/video_0281...
# Getting sequence data for ./images/video_0283...
# Getting sequence data for ./images/video_0283...
# Getting sequence data for ./images/video_0286...
# Getting sequence data for ./images/video_0290...
# Getting sequence data for ./images/video_0290...
# Getting sequence data for ./images/video_0293...
# Getting sequence data for ./images/video_0293...
# Getting sequence data for ./images/video_0293...
# Getting sequence data for ./images/video_0293...
# Getting sequence data for ./images/video_0293...
# Getting sequence data for ./images/video_0293...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0297...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0298...
# Getting sequence data for ./images/video_0301...
# Getting sequence data for ./images/video_0301...
# Getting sequence data for ./images/video_0301...
# Getting sequence data for ./images/video_0301...
# Getting sequence data for ./images/video_0302...
# Getting sequence data for ./images/video_0302...
# Getting sequence data for ./images/video_0302...
# Getting sequence data for ./images/video_0310...
# Getting sequence data for ./images/video_0310...
# Getting sequence data for ./images/video_0311...
# Getting sequence data for ./images/video_0311...
# Getting sequence data for ./images/video_0311...
# Getting sequence data for ./images/video_0311...
# Getting sequence data for ./images/video_0312...
# Getting sequence data for ./images/video_0312...
# Getting sequence data for ./images/video_0312...
# Getting sequence data for ./images/video_0315...
# Getting sequence data for ./images/video_0315...
# Getting sequence data for ./images/video_0315...
# Getting sequence data for ./images/video_0315...
# Getting sequence data for ./images/video_0317...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0318...
# Getting sequence data for ./images/video_0319...
# Getting sequence data for ./images/video_0320...
# Getting sequence data for ./images/video_0320...
# Getting sequence data for ./images/video_0320...
# Getting sequence data for ./images/video_0321...
# Getting sequence data for ./images/video_0321...
# Getting sequence data for ./images/video_0321...
# Getting sequence data for ./images/video_0321...
# Getting sequence data for ./images/video_0321...
# Getting sequence data for ./images/video_0324...
# Getting sequence data for ./images/video_0324...
# Getting sequence data for ./images/video_0324...
# Getting sequence data for ./images/video_0324...
# Getting sequence data for ./images/video_0325...
# Getting sequence data for ./images/video_0325...
# Getting sequence data for ./images/video_0326...
# Getting sequence data for ./images/video_0326...
# Getting sequence data for ./images/video_0326...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0331...
# Getting sequence data for ./images/video_0335...
# Getting sequence data for ./images/video_0335...
# Getting sequence data for ./images/video_0335...
# Getting sequence data for ./images/video_0335...
# Getting sequence data for ./images/video_0335...
# Getting sequence data for ./images/video_0335...
# Getting sequence data for ./images/video_0341...
# Getting sequence data for ./images/video_0341...
# Getting sequence data for ./images/video_0341...
# Getting sequence data for ./images/video_0341...
# Getting sequence data for ./images/video_0342...
# Getting sequence data for ./images/video_0342...
# Getting sequence data for ./images/video_0345...
# Getting sequence data for ./images/video_0345...
# Getting sequence data for ./images/video_0345...
# Getting sequence data for ./images/video_0346...
# Getting sequence data for ./images/video_0002...
# Getting sequence data for ./images/video_0002...
# Getting sequence data for ./images/video_0006...
# Getting sequence data for ./images/video_0006...
# Getting sequence data for ./images/video_0006...
# Getting sequence data for ./images/video_0006...
# Getting sequence data for ./images/video_0040...
# Getting sequence data for ./images/video_0040...
# Getting sequence data for ./images/video_0040...
# Getting sequence data for ./images/video_0041...
# Getting sequence data for ./images/video_0065...
# Getting sequence data for ./images/video_0065...
# Getting sequence data for ./images/video_0065...
# Getting sequence data for ./images/video_0073...
# Getting sequence data for ./images/video_0073...
# Getting sequence data for ./images/video_0082...
# Getting sequence data for ./images/video_0089...
# Getting sequence data for ./images/video_0089...
# Getting sequence data for ./images/video_0102...
# Getting sequence data for ./images/video_0102...
# Getting sequence data for ./images/video_0102...
# Getting sequence data for ./images/video_0102...
# Getting sequence data for ./images/video_0156...
# Getting sequence data for ./images/video_0156...
# Getting sequence data for ./images/video_0160...
# Getting sequence data for ./images/video_0160...
# Getting sequence data for ./images/video_0160...
# Getting sequence data for ./images/video_0170...
# Getting sequence data for ./images/video_0181...
# Getting sequence data for ./images/video_0193...
# Getting sequence data for ./images/video_0199...
# Getting sequence data for ./images/video_0217...
# Getting sequence data for ./images/video_0226...
# Getting sequence data for ./images/video_0252...
# Getting sequence data for ./images/video_0252...
# Getting sequence data for ./images/video_0252...
# Getting sequence data for ./images/video_0263...
# Getting sequence data for ./images/video_0263...
# Getting sequence data for ./images/video_0263...
# Getting sequence data for ./images/video_0263...
# Getting sequence data for ./images/video_0274...
# Getting sequence data for ./images/video_0274...
# Getting sequence data for ./images/video_0274...
# Getting sequence data for ./images/video_0291...
# Getting sequence data for ./images/video_0291...
# Getting sequence data for ./images/video_0303...
# Getting sequence data for ./images/video_0303...
# Getting sequence data for ./images/video_0303...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0306...
# Getting sequence data for ./images/video_0340...
# Getting sequence data for ./images/video_0340...
# Getting sequence data for ./images/video_0340...
# Getting sequence data for ./images/video_0340...
# Getting sequence data for ./images/video_0005...
# Getting sequence data for ./images/video_0005...
# Getting sequence data for ./images/video_0005...
# Getting sequence data for ./images/video_0005...
# Getting sequence data for ./images/video_0016...
# Getting sequence data for ./images/video_0016...
# Getting sequence data for ./images/video_0016...
# Getting sequence data for ./images/video_0016...
# Getting sequence data for ./images/video_0016...
# Getting sequence data for ./images/video_0017...
# Getting sequence data for ./images/video_0017...
# Getting sequence data for ./images/video_0023...
# Getting sequence data for ./images/video_0023...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0028...
# Getting sequence data for ./images/video_0032...
# Getting sequence data for ./images/video_0042...
# Getting sequence data for ./images/video_0045...
# Getting sequence data for ./images/video_0045...
# Getting sequence data for ./images/video_0045...
# Getting sequence data for ./images/video_0046...
# Getting sequence data for ./images/video_0048...
# Getting sequence data for ./images/video_0053...
# Getting sequence data for ./images/video_0053...
# Getting sequence data for ./images/video_0055...
# Getting sequence data for ./images/video_0059...
# Getting sequence data for ./images/video_0059...
# Getting sequence data for ./images/video_0059...
# Getting sequence data for ./images/video_0063...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0067...
# Getting sequence data for ./images/video_0071...
# Getting sequence data for ./images/video_0071...
# Getting sequence data for ./images/video_0071...
# Getting sequence data for ./images/video_0075...
# Getting sequence data for ./images/video_0075...
# Getting sequence data for ./images/video_0075...
# Getting sequence data for ./images/video_0076...
# Getting sequence data for ./images/video_0076...
# Getting sequence data for ./images/video_0076...
# Getting sequence data for ./images/video_0076...
# Getting sequence data for ./images/video_0084...
# Getting sequence data for ./images/video_0087...
# Getting sequence data for ./images/video_0087...
# Getting sequence data for ./images/video_0090...
# Getting sequence data for ./images/video_0092...
# Getting sequence data for ./images/video_0092...
# Getting sequence data for ./images/video_0092...
# Getting sequence data for ./images/video_0093...
# Getting sequence data for ./images/video_0093...
# Getting sequence data for ./images/video_0096...
# Getting sequence data for ./images/video_0100...
# Getting sequence data for ./images/video_0101...
# Getting sequence data for ./images/video_0104...
# Getting sequence data for ./images/video_0105...
# Getting sequence data for ./images/video_0106...
# Getting sequence data for ./images/video_0106...
# Getting sequence data for ./images/video_0106...
# Getting sequence data for ./images/video_0110...
# Getting sequence data for ./images/video_0110...
# Getting sequence data for ./images/video_0113...
# Getting sequence data for ./images/video_0113...
# Getting sequence data for ./images/video_0115...
# Getting sequence data for ./images/video_0116...
# Getting sequence data for ./images/video_0116...
# Getting sequence data for ./images/video_0117...
# Getting sequence data for ./images/video_0117...
# Getting sequence data for ./images/video_0117...
# Getting sequence data for ./images/video_0117...
# Getting sequence data for ./images/video_0117...
# Getting sequence data for ./images/video_0118...
# Getting sequence data for ./images/video_0118...
# Getting sequence data for ./images/video_0118...
# Getting sequence data for ./images/video_0124...
# Getting sequence data for ./images/video_0124...
# Getting sequence data for ./images/video_0124...
# Getting sequence data for ./images/video_0124...
# Getting sequence data for ./images/video_0125...
# Getting sequence data for ./images/video_0127...
# Getting sequence data for ./images/video_0128...
# Getting sequence data for ./images/video_0128...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0135...
# Getting sequence data for ./images/video_0141...
# Getting sequence data for ./images/video_0141...
# Getting sequence data for ./images/video_0144...
# Getting sequence data for ./images/video_0144...
# Getting sequence data for ./images/video_0144...
# Getting sequence data for ./images/video_0144...
# Getting sequence data for ./images/video_0144...
# Getting sequence data for ./images/video_0148...
# Getting sequence data for ./images/video_0148...
# Getting sequence data for ./images/video_0150...
# Getting sequence data for ./images/video_0150...
# Getting sequence data for ./images/video_0150...
# Getting sequence data for ./images/video_0150...
# Getting sequence data for ./images/video_0152...
# Getting sequence data for ./images/video_0152...
# Getting sequence data for ./images/video_0152...
# Getting sequence data for ./images/video_0153...
# Getting sequence data for ./images/video_0153...
# Getting sequence data for ./images/video_0153...
# Getting sequence data for ./images/video_0153...
# Getting sequence data for ./images/video_0155...
# Getting sequence data for ./images/video_0163...
# Getting sequence data for ./images/video_0163...
# Getting sequence data for ./images/video_0164...
# Getting sequence data for ./images/video_0164...
# Getting sequence data for ./images/video_0164...
# Getting sequence data for ./images/video_0164...
# Getting sequence data for ./images/video_0165...
# Getting sequence data for ./images/video_0165...
# Getting sequence data for ./images/video_0165...
# Getting sequence data for ./images/video_0165...
# Getting sequence data for ./images/video_0173...
# Getting sequence data for ./images/video_0173...
# Getting sequence data for ./images/video_0177...
# Getting sequence data for ./images/video_0177...
# Getting sequence data for ./images/video_0177...
# Getting sequence data for ./images/video_0178...
# Getting sequence data for ./images/video_0178...
# Getting sequence data for ./images/video_0178...
# Getting sequence data for ./images/video_0178...
# Getting sequence data for ./images/video_0178...
# Getting sequence data for ./images/video_0178...
# Getting sequence data for ./images/video_0183...
# Getting sequence data for ./images/video_0183...
# Getting sequence data for ./images/video_0187...
# Getting sequence data for ./images/video_0187...
# Getting sequence data for ./images/video_0197...
# Getting sequence data for ./images/video_0201...
# Getting sequence data for ./images/video_0201...
# Getting sequence data for ./images/video_0201...
# Getting sequence data for ./images/video_0201...
# Getting sequence data for ./images/video_0203...
# Getting sequence data for ./images/video_0203...
# Getting sequence data for ./images/video_0203...
# Getting sequence data for ./images/video_0206...
# Getting sequence data for ./images/video_0206...
# Getting sequence data for ./images/video_0206...
# Getting sequence data for ./images/video_0206...
# Getting sequence data for ./images/video_0206...
# Getting sequence data for ./images/video_0211...
# Getting sequence data for ./images/video_0211...
# Getting sequence data for ./images/video_0211...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0212...
# Getting sequence data for ./images/video_0213...
# Getting sequence data for ./images/video_0213...
# Getting sequence data for ./images/video_0213...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0221...
# Getting sequence data for ./images/video_0222...
# Getting sequence data for ./images/video_0222...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0223...
# Getting sequence data for ./images/video_0224...
# Getting sequence data for ./images/video_0224...
# Getting sequence data for ./images/video_0224...
# Getting sequence data for ./images/video_0224...
# Getting sequence data for ./images/video_0230...
# Getting sequence data for ./images/video_0234...
# Getting sequence data for ./images/video_0234...
# Getting sequence data for ./images/video_0234...
# Getting sequence data for ./images/video_0234...
# Getting sequence data for ./images/video_0238...
# Getting sequence data for ./images/video_0238...
# Getting sequence data for ./images/video_0244...
# Getting sequence data for ./images/video_0244...
# Getting sequence data for ./images/video_0244...
# Getting sequence data for ./images/video_0244...
# Getting sequence data for ./images/video_0244...
# Getting sequence data for ./images/video_0244...
# Getting sequence data for ./images/video_0245...
# Getting sequence data for ./images/video_0245...
# Getting sequence data for ./images/video_0245...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0251...
# Getting sequence data for ./images/video_0253...
# Getting sequence data for ./images/video_0253...
# Getting sequence data for ./images/video_0265...
# Getting sequence data for ./images/video_0265...
# Getting sequence data for ./images/video_0265...
# Getting sequence data for ./images/video_0265...
# Getting sequence data for ./images/video_0265...
# Getting sequence data for ./images/video_0265...
# Getting sequence data for ./images/video_0267...
# Getting sequence data for ./images/video_0267...
# Getting sequence data for ./images/video_0270...
# Getting sequence data for ./images/video_0271...
# Getting sequence data for ./images/video_0271...
# Getting sequence data for ./images/video_0277...
# Getting sequence data for ./images/video_0277...
# Getting sequence data for ./images/video_0277...
# Getting sequence data for ./images/video_0277...
# Getting sequence data for ./images/video_0278...
# Getting sequence data for ./images/video_0278...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0279...
# Getting sequence data for ./images/video_0287...
# Getting sequence data for ./images/video_0288...
# Getting sequence data for ./images/video_0292...
# Getting sequence data for ./images/video_0292...
# Getting sequence data for ./images/video_0294...
# Getting sequence data for ./images/video_0295...
# Getting sequence data for ./images/video_0295...
# Getting sequence data for ./images/video_0295...
# Getting sequence data for ./images/video_0295...
# Getting sequence data for ./images/video_0299...
# Getting sequence data for ./images/video_0299...
# Getting sequence data for ./images/video_0299...
# Getting sequence data for ./images/video_0299...
# Getting sequence data for ./images/video_0299...
# Getting sequence data for ./images/video_0299...
# Getting sequence data for ./images/video_0300...
# Getting sequence data for ./images/video_0304...
# Getting sequence data for ./images/video_0305...
# Getting sequence data for ./images/video_0305...
# Getting sequence data for ./images/video_0305...
# Getting sequence data for ./images/video_0305...
# Getting sequence data for ./images/video_0305...
# Getting sequence data for ./images/video_0307...
# Getting sequence data for ./images/video_0307...
# Getting sequence data for ./images/video_0307...
# Getting sequence data for ./images/video_0308...
# Getting sequence data for ./images/video_0309...
# Getting sequence data for ./images/video_0309...
# Getting sequence data for ./images/video_0309...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0313...
# Getting sequence data for ./images/video_0314...
# Getting sequence data for ./images/video_0314...
# Getting sequence data for ./images/video_0316...
# Getting sequence data for ./images/video_0316...
# Getting sequence data for ./images/video_0316...
# Getting sequence data for ./images/video_0322...
# Getting sequence data for ./images/video_0322...
# Getting sequence data for ./images/video_0322...
# Getting sequence data for ./images/video_0322...
# Getting sequence data for ./images/video_0327...
# Getting sequence data for ./images/video_0327...
# Getting sequence data for ./images/video_0327...
# Getting sequence data for ./images/video_0327...
# Getting sequence data for ./images/video_0327...
# Getting sequence data for ./images/video_0329...
# Getting sequence data for ./images/video_0329...
# Getting sequence data for ./images/video_0330...
# Getting sequence data for ./images/video_0330...
# Getting sequence data for ./images/video_0334...
# Getting sequence data for ./images/video_0334...
# Getting sequence data for ./images/video_0334...
# Getting sequence data for ./images/video_0336...
# Getting sequence data for ./images/video_0336...
# Getting sequence data for ./images/video_0337...
# Getting sequence data for ./images/video_0337...
# Getting sequence data for ./images/video_0337...
# Getting sequence data for ./images/video_0337...
# Getting sequence data for ./images/video_0338...
# Getting sequence data for ./images/video_0338...
# Getting sequence data for ./images/video_0338...
# Getting sequence data for ./images/video_0338...
# Getting sequence data for ./images/video_0344...
# Getting sequence data for ./images/video_0344...
# Getting sequence data for ./images/video_0344...
# Getting sequence data for ./images/video_0344...
# Getting sequence data for ./images/video_0344...

# %%
def get_features(data_dict, split="train"):
    seq_features = np.array([[0,0]])
    all_features = {}
    with open(os.getcwd() + "/pose_features_" + split + "/features.csv", "ab") as w:
        for i in range(len(data_dict['image_seq'])):
            print("SEQUENCE " + str(i))
            for j in range(len(data_dict['image_seq'][i])):
                seq_feature = img_inference(data_dict['image_seq'][i][j], data_dict['bbox_seq'][i][j])
#                 print(len(seq_feature))
                seq_features = np.append(seq_features, seq_feature)
            seq_features = np.append(seq_features, [data_dict['activities_seq'][i][j]])
#             print(len(seq_features[2:]))
            np.savetxt(w, [seq_features], delimiter=",")
            all_features[split + "_seq_" + str(i)] = seq_features[2:]
            seq_features = np.array([0,0])
        return all_features

# %%
all_features = get_features(train_seq)
# Out:
# SEQUENCE 0
# SEQUENCE 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-8c7bd4dc65b2> in <module>
# ----> 1 all_features = get_features(train_seq)
#
# <ipython-input-15-5f9a8307af4e> in get_features(data_dict, split)
#       6             print("SEQUENCE " + str(i))
#       7             for j in range(len(data_dict['image_seq'][i])):
# ----> 8                 seq_feature = img_inference(data_dict['image_seq'][i][j], data_dict['bbox_seq'][i][j])
#       9 #                 print(len(seq_feature))
#      10                 seq_features = np.append(seq_features, seq_feature)
#
# ~/niviru/poseflow-pie/Pose Estimation/pose_estimation.py in img_inference(img, bbox)
#     394     scale_param = [0.5, 1.0, 1.5, 2.0]
#     395 #     print("getting initial pafs and heatmap...")
# --> 396     paf_info, heatmap_info = get_paf_and_heatmap(model_pose, im, scale_param)
#     397 #     print("FINISHED")
#     398 #     print("extracting heatmaps...")
#
# ~/niviru/poseflow-pie/Pose Estimation/pose_estimation.py in get_paf_and_heatmap(model, img_raw, scale_search, param_stride, box_size)
#     188         paf = nn.UpsamplingBilinear2d((img_raw.shape[0], img_raw.shape[1]))(output1)
#     189
# --> 190         heatmap_avg[i] = heatmap[0].data
#     191         paf_avg[i] = paf[0].data
#     192
#
# KeyboardInterrupt:

# %%
import csv
arr = [np.squeeze(np.array([[2, 2, 3]]))]
with open(os.getcwd() + "/pose_features_" + "train" + "/features.csv", "ab") as f:
#     for i in range(3):
    np.savetxt(f, arr, delimiter=",")
# writer=csv.writer(f)
# writer.writerow(arr)
