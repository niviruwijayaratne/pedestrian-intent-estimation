# %%
import pandas as pd
import numpy as np

# %%
xnames = []
ynames = []
angle_names = []
for i in range(1, 10):
    for j in range(i + 1, 10):
        xnames.append("xd" + str(i) + str(j))
        ynames.append("yd" + str(i) + str(j))
        angle_names.append("phi1" + str(i) + str(j))
        angle_names.append("phi2" + str(i) + str(j))
        
triangle_names = []
for i in range(1, 10):
    for j in range(1, 10):
        if j == i:
            continue
        for k in range(j + 1, 10):
            if k == i:
                continue
            triangle_names.append("theta" + str(i) + str(j) + str(k))

# %%
colnames = []
colnames.extend(xnames)
colnames.extend(ynames)
colnames.extend(angle_names)
colnames.extend(triangle_names)

# %%
names = []
for i in range(1, 15):
    names.extend(colnames)
names.append("label")

# %%
for i in range(1, 15):
    for j in range(396*(i-1), 396*i):
        names[j] += "_frame" + str(i)

# %%
df = pd.read_csv("pose_features_train/final_features.csv", header=0, names=names) 
df
# Out:
#       xd12_frame1  xd13_frame1  xd14_frame1  xd15_frame1  xd16_frame1  \
# 0        0.213115     0.103825     0.016393     0.153005     0.049180
# 1        0.219780     0.109890     0.016484     0.148352     0.060440
# 2        0.194595     0.097297     0.005405     0.151351     0.054054
# 3        0.195652     0.097826     0.010870     0.157609     0.054348
# 4        0.206522     0.103261     0.005435     0.146739     0.048913
# ...           ...          ...          ...          ...          ...
# 2416     0.012821     0.115385     0.025641     0.153846     0.012821
# 2417     0.100719     0.046763     0.010791     0.089928     0.025180
# 2418     0.101449     0.050725     0.003623     0.086957     0.003623
# 2419     0.085911     0.041237     0.010309     0.079038     0.013746
# 2420     0.091873     0.042403     0.010601     0.084806     0.014134
#
#       xd17_frame1  xd18_frame1  xd19_frame1  xd23_frame1  xd24_frame1  ...  \
# 0        0.081967     0.065574     0.043716     0.109290     0.196721  ...
# 1        0.082418     0.060440     0.027473     0.109890     0.203297  ...
# 2        0.081081     0.021622     0.016216     0.097297     0.189189  ...
# 3        0.086957     0.021739     0.021739     0.097826     0.184783  ...
# 4        0.076087     0.070652     0.021739     0.103261     0.201087  ...
# ...           ...          ...          ...          ...          ...  ...
# 2416     0.128205     0.000000     0.153846     0.128205     0.038462  ...
# 2417     0.115108     0.068345     0.079137     0.053957     0.089928  ...
# 2418     0.112319     0.057971     0.054348     0.050725     0.097826  ...
# 2419     0.103093     0.003436     0.020619     0.044674     0.075601  ...
# 2420     0.130742     0.017668     0.024735     0.049470     0.081272  ...
#
#       theta946_frame14  theta947_frame14  theta948_frame14  theta956_frame14  \
# 0             0.001029          0.001495          0.005838          0.002448
# 1             0.001272          0.001547          0.006285          0.002648
# 2             0.001287          0.001546          0.006290          0.002647
# 3             0.001643          0.001558          0.006524          0.003052
# 4             0.001599          0.001506          0.006600          0.002981
# ...                ...               ...               ...               ...
# 2416          0.000994          0.003205          0.026634          0.002163
# 2417          0.000896          0.000522          0.003789          0.001418
# 2418          0.000925          0.000556          0.003839          0.001354
# 2419          0.000503          0.000559          0.003974          0.000906
# 2420          0.000466          0.000670          0.004617          0.000900
#
#       theta957_frame14  theta958_frame14  theta967_frame14  theta968_frame14  \
# 0         7.617706e-05          0.007257          0.002524          0.004809
# 1         1.713771e-04          0.007661          0.002820          0.005013
# 2         1.857198e-04          0.007651          0.002833          0.005003
# 3         1.487147e-04          0.007934          0.003201          0.004882
# 4         1.239710e-04          0.007982          0.003105          0.005001
# ...                ...               ...               ...               ...
# 2416      4.782376e-05          0.029792          0.002211          0.027628
# 2417      3.668562e-07          0.004311          0.001418          0.002893
# 2418      1.269077e-04          0.004268          0.001481          0.002913
# 2419      1.553980e-04          0.004377          0.001062          0.003471
# 2420      2.364973e-04          0.005050          0.001136          0.004151
#
#       theta978_frame14  label
# 0             0.007333    0.0
# 1             0.007833    0.0
# 2             0.007837    0.0
# 3             0.008083    0.0
# 4             0.008106    0.0
# ...                ...    ...
# 2416          0.029840    0.0
# 2417          0.004311    1.0
# 2418          0.004395    1.0
# 2419          0.004533    1.0
# 2420          0.005287    1.0
#
# [2421 rows x 5545 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values

# %%
Y[0:2]
# Out:
# array([0., 0.])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=400, random_state=0, max_depth = 15)
classifier.fit(X_train, y_train)
